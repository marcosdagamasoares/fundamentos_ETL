# %% [markdown]
# pip install pandas
# pip install pandera

# %%
import pandas as pd
import pandera as pa
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %% [markdown]
# C:\CURSOS\BOOTCAMP\FUNDAMENTOS DE ETLCarregar csv

# %%
# dataframe = pd.read_csv("/cursos/bootcamp/fundamentos de etl/ocorrencia_2010_2020.csv", sep=';')
dataframe = pd.read_csv("ocorrencia_2010_2020.csv", sep=';')
dataframe.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 ****     03/01/2010        12:00:00
# 1          BRASIL                 SBBE     03/01/2010        11:05:00
# 2          BRASIL                 SBRJ     03/01/2010        03:00:00
# 3          BRASIL                 ****     04/01/2010        17:30:00
# 4          BRASIL                 SBPK     05/01/2010        19:25:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM          FINALIZADA
# 1                            SIM          FINALIZADA
# 2                            SIM          FINALIZADA
# 3                            SIM          FINALIZADA
# 4                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                         NaN                            NÃO
# 2                         NaN                            NÃO
# 3           A-539/CENIPA/2018                            SIM
# 4                         NaN                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
# 2                       NaN                    0                           1
# 3                2019-10-28                    0                           1
# 4                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                    NÃO
# 2                    NÃO
# 3                    NÃO
# 4                    NÃO

# %%
dataframe = pd.read_csv("/cursos/bootcamp/fundamentos de etl/ocorrencia_2010_2020.csv", sep=';')
dataframe.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***    RIO DE JANEIRO            RJ
# 1                 NaN                  NaN             BELÉM            PA
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 ****     03/01/2010        12:00:00
# 1          BRASIL                 SBBE     03/01/2010        11:05:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM          FINALIZADA
# 1                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                         NaN                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                    NÃO

# %%
pip
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\program' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
# parse_date - fazer o parser do campo que está como objeto para data
# ocorrencia_dia passa a ser datetime64[ns]
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'])
df.head(2)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***    RIO DE JANEIRO            RJ
# 1                 NaN                  NaN             BELÉM            PA
#
#   ocorrencia_pais ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0          BRASIL                 ****     2010-03-01        12:00:00
# 1          BRASIL                 SBBE     2010-03-01        11:05:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            SIM          FINALIZADA
# 1                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1                         NaN                            NÃO
#
#   divulgacao_dia_publicacao  total_recomendacoes  total_aeronaves_envolvidas  \
# 0                       NaN                    0                           1
# 1                       NaN                    0                           1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                    NÃO

# %% [markdown]
# VISUALIZAR OS TIPO DE DADOS
# ocorrecia_dia:  está como objeto mas é data

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %%
# Acesso o campo ocorrencia_data
df.ocorrencia_dia.head(5)
# Out:
# 0   2010-03-01
# 1   2010-03-01
# 2   2010-03-01
# 3   2010-04-01
# 4   2010-05-01
# Name: ocorrencia_dia, dtype: datetime64[ns]

# %% [markdown]
# EXTRAÇÃO DO MÊS DE UMA DATA

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        4
# 4        5
#         ..
# 5747    12
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %% [markdown]
# Campo "ocorrencia_dia" o dia e mês estão invertidos, vendo como está o arquivo CSV aberto pelo Microsft Excel

# %%
# parse_date - fazer o parser do campo que está como objeto para data
# ocorrencia_dia passa a ser datetime64[ns]
# dayfirst - no arquivo origem dos dados, o primeiro valor é o dia, ficando igual ao arquivo origem
# O Primeiro valor é o dia
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(2)

# %% [markdown]
# tail: traz os últimos registros
# Campo data vazia, vira como: NaT
# Se campo texto vazio: NaN

# %%
df.tail(2)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 5750          -22.507222           -54.364167         VICENTINA            MS
# 5751            -22,9875               -43,37    RIO DE JANEIRO            RJ
#
#       ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 5750  ...     2020-12-31        09:00:00                            SIM
# 5751  ...     2020-12-31        13:24:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 5750          FINALIZADA                         ***
# 5751          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 5750                            NÃO                       NaN
# 5751                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 5750                   0                          1                     NÃO
# 5751                   0                          1                     NÃO
#
# [2 rows x 22 columns]

# %% [markdown]
# VALIDAÇÃO DOS TIPOS DE DADOS
# os CAMPOS objects são texto, não há problema trabalhar com objcts
# Se o campo (ocorrencia_dia) estiver (03/50/2010) ao verficar o tipo
# retornará como objeto, mesmo fazendo parse_dates=['ocorrencia_dia']  o parse não
# é feito e não terei a validação

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# total_aeronaves_envolvidas                 int64
# ocorrencia_saida_pista                    object
# dtype: object

# %% [markdown]
# Para não ocorrer o problema acima referente a data, USAR a BIBLIOTECA ( pandera ) - import pandera as pa
# que permite montar um esquema de validação deste dataframe, esse esquema vai validar se a coluna
# ( ocorrencia_dia ) é do tipo ( data ) se não for do tipo data o processo irá parar, ocorrerá uma
# exceção

# %% [markdown]
# Iniciar essa sequencia de código é importante, caso execute todos os códigos do notebook, essa sequencia
# garante que as dependências de cada função sejam satisfeitas

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
# 4                 NaN                  NaN             PELOTAS            RS
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  ...     2010-01-03        12:00:00                            SIM
# 1  ...     2010-01-03        11:05:00                            SIM
# 2  ...     2010-01-03        03:00:00                            SIM
# 3  ...     2010-01-04        17:30:00                            SIM
# 4  ...     2010-01-05        19:25:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# 1          FINALIZADA                         NaN
# 2          FINALIZADA                         NaN
# 3          FINALIZADA           A-539/CENIPA/2018
# 4          FINALIZADA                         NaN
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
# 1                            NÃO                       NaN
# 2                            NÃO                       NaN
# 3                            SIM                2019-10-28
# 4                            NÃO                       NaN
#
#   total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                          1                     NÃO
# 1                   0                          1                     NÃO
# 2                   0                          1                     NÃO
# 3                   0                          1                     NÃO
# 4                   0                          1                     NÃO
#
# [5 rows x 22 columns]

# %% [markdown]
# MONTAR O ESQUEMA
# A função DataFrameSchema(): traz o schema

# %%
schema = pa.DataFrameSchema(
        columns = {
            "codigo_ocorrencia":pa.Column(pa.Int)
        }
)

# %% [markdown]
# validate(): VALIDAÇÃO DO DATAFRAME
# A EXECUÇÃO NORMAL DO validate() significa foi validado mediante a coluna ( codigo_ocorrencia )
# e ESSA COLUNA POSSUI DADOS DO TIPO INTEIRO

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 5747      -23.0069444444       -47.1344444444            CAMPINAS
# 5748          -10.804722           -49.756389   LAGOA DA CONFUSÃO
# 5749              -22.81      -43.25055555555      RIO DE JANEIRO
# 5750          -22.507222           -54.364167           VICENTINA
# 5751            -22,9875               -43,37      RIO DE JANEIRO
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 5747            SP  ...     2020-12-29        19:00:00
# 5748            TO  ...     2020-12-30        18:30:00
# 5749            RJ  ...     2020-12-30        00:54:00
# 5750            MS  ...     2020-12-31        09:00:00
# 5751            RJ  ...     2020-12-31        13:24:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 5747                            SIM          FINALIZADA
# 5748                            SIM          FINALIZADA
# 5749                            SIM          FINALIZADA
# 5750                            SIM          FINALIZADA
# 5751                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 5747                         ***                            NÃO
# 5748                         ***                            NÃO
# 5749                         ***                            NÃO
# 5750                         ***                            NÃO
# 5751                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 5747                       NaN                   0                          1
# 5748                       NaN                   0                          1
# 5749                       NaN                   0                          1
# 5750                       NaN                   0                          1
# 5751                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 5747                     NÃO
# 5748                     NÃO
# 5749                     NÃO
# 5750                     NÃO
# 5751                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# Colunas , Validação das Colunas
# Cada coluna com seu tipo de dado
# ocorrencia_dia do tipo (string) futuramente colocar verificação
# de formato de hora para 24 hs utilizando expressão regular

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, nullable=True),
        "total_recomendacoes": pa.Column(pa.Int) 
    }
)

# %% [markdown]
# VALIDAR O DATAFRAME COM BASE NO NOVO SCHEMA
# Dará erro: SchemaError: non-nullable series 'ocorrencia_hora' contains null values: {4100: nan}
# nullable=True - Ignora campo vazio

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 5747      -23.0069444444       -47.1344444444            CAMPINAS
# 5748          -10.804722           -49.756389   LAGOA DA CONFUSÃO
# 5749              -22.81      -43.25055555555      RIO DE JANEIRO
# 5750          -22.507222           -54.364167           VICENTINA
# 5751            -22,9875               -43,37      RIO DE JANEIRO
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 5747            SP  ...     2020-12-29        19:00:00
# 5748            TO  ...     2020-12-30        18:30:00
# 5749            RJ  ...     2020-12-30        00:54:00
# 5750            MS  ...     2020-12-31        09:00:00
# 5751            RJ  ...     2020-12-31        13:24:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 5747                            SIM          FINALIZADA
# 5748                            SIM          FINALIZADA
# 5749                            SIM          FINALIZADA
# 5750                            SIM          FINALIZADA
# 5751                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 5747                         ***                            NÃO
# 5748                         ***                            NÃO
# 5749                         ***                            NÃO
# 5750                         ***                            NÃO
# 5751                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 5747                       NaN                   0                          1
# 5748                       NaN                   0                          1
# 5749                       NaN                   0                          1
# 5750                       NaN                   0                          1
# 5751                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 5747                     NÃO
# 5748                     NÃO
# 5749                     NÃO
# 5750                     NÃO
# 5751                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# VALIDAÇÃO DA COLUNA ocorrencia_hora, seu tipo de dados é "string"
# Estabelecer um formato de Hora:Minuto:Segundo
# Usar o recurso de restrição através de expressão regular

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String),
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int) 
    }
)

# %% [markdown]
# VALIDAR O DATAFRAME COM BASE NAS ALTERAÇÕES DO schema

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 5747      -23.0069444444       -47.1344444444            CAMPINAS
# 5748          -10.804722           -49.756389   LAGOA DA CONFUSÃO
# 5749              -22.81      -43.25055555555      RIO DE JANEIRO
# 5750          -22.507222           -54.364167           VICENTINA
# 5751            -22,9875               -43,37      RIO DE JANEIRO
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 5747            SP  ...     2020-12-29        19:00:00
# 5748            TO  ...     2020-12-30        18:30:00
# 5749            RJ  ...     2020-12-30        00:54:00
# 5750            MS  ...     2020-12-31        09:00:00
# 5751            RJ  ...     2020-12-31        13:24:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 5747                            SIM          FINALIZADA
# 5748                            SIM          FINALIZADA
# 5749                            SIM          FINALIZADA
# 5750                            SIM          FINALIZADA
# 5751                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 5747                         ***                            NÃO
# 5748                         ***                            NÃO
# 5749                         ***                            NÃO
# 5750                         ***                            NÃO
# 5751                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 5747                       NaN                   0                          1
# 5748                       NaN                   0                          1
# 5749                       NaN                   0                          1
# 5750                       NaN                   0                          1
# 5751                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 5747                     NÃO
# 5748                     NÃO
# 5749                     NÃO
# 5750                     NÃO
# 5751                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# TRATAMENTO DO TAMANHO DO DADO
# CAMPO ocorrencia_uf máximo e minimo caracteres ou nulo
# Usar: lenght(2,2) - tamanho mínimo e máximo

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2": pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),        
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),        
        "ocorrencia_aerodromo": pa.Column(pa.String),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int) 
    }
)

# %% [raw]
# VALIDAR - validação passou

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# 2                  40351               40351                INCIDENTE
# 3                  39527               39527                 ACIDENTE
# 4                  40324               40324                INCIDENTE
# ...                  ...                 ...                      ...
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 0                    ***                  ***      RIO DE JANEIRO
# 1                    NaN                  NaN               BELÉM
# 2                    NaN                  NaN      RIO DE JANEIRO
# 3         -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE
# 4                    NaN                  NaN             PELOTAS
# ...                  ...                  ...                 ...
# 5747      -23.0069444444       -47.1344444444            CAMPINAS
# 5748          -10.804722           -49.756389   LAGOA DA CONFUSÃO
# 5749              -22.81      -43.25055555555      RIO DE JANEIRO
# 5750          -22.507222           -54.364167           VICENTINA
# 5751            -22,9875               -43,37      RIO DE JANEIRO
#
#      ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0               RJ  ...     2010-01-03        12:00:00
# 1               PA  ...     2010-01-03        11:05:00
# 2               RJ  ...     2010-01-03        03:00:00
# 3               MT  ...     2010-01-04        17:30:00
# 4               RS  ...     2010-01-05        19:25:00
# ...            ...  ...            ...             ...
# 5747            SP  ...     2020-12-29        19:00:00
# 5748            TO  ...     2020-12-30        18:30:00
# 5749            RJ  ...     2020-12-30        00:54:00
# 5750            MS  ...     2020-12-31        09:00:00
# 5751            RJ  ...     2020-12-31        13:24:00
#
#      investigacao_aeronave_liberada investigacao_status  \
# 0                               SIM          FINALIZADA
# 1                               SIM          FINALIZADA
# 2                               SIM          FINALIZADA
# 3                               SIM          FINALIZADA
# 4                               SIM          FINALIZADA
# ...                             ...                 ...
# 5747                            SIM          FINALIZADA
# 5748                            SIM          FINALIZADA
# 5749                            SIM          FINALIZADA
# 5750                            SIM          FINALIZADA
# 5751                            SIM          FINALIZADA
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                            ***                            NÃO
# 1                            NaN                            NÃO
# 2                            NaN                            NÃO
# 3              A-539/CENIPA/2018                            SIM
# 4                            NaN                            NÃO
# ...                          ...                            ...
# 5747                         ***                            NÃO
# 5748                         ***                            NÃO
# 5749                         ***                            NÃO
# 5750                         ***                            NÃO
# 5751                         ***                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                          NaN                   0                          1
# 1                          NaN                   0                          1
# 2                          NaN                   0                          1
# 3                   2019-10-28                   0                          1
# 4                          NaN                   0                          1
# ...                        ...                 ...                        ...
# 5747                       NaN                   0                          1
# 5748                       NaN                   0                          1
# 5749                       NaN                   0                          1
# 5750                       NaN                   0                          1
# 5751                       NaN                   0                          1
#
#       ocorrencia_saida_pista
# 0                        NÃO
# 1                        NÃO
# 2                        NÃO
# 3                        NÃO
# 4                        NÃO
# ...                      ...
# 5747                     NÃO
# 5748                     NÃO
# 5749                     NÃO
# 5750                     NÃO
# 5751                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# LIMPEZA DOS DADOS
