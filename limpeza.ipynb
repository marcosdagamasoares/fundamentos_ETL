# %%
import pandas as pd
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %% [markdown]
# Localizar na Linha 1  e coluna (ocorrencia_cidade )

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %% [markdown]
# PEGAR OS DADOS DE TODA UMA LINHA, POR EXEMPLO LINHA 3
# def.loc[indice da linha]

# %%
df.loc[3]
# Out:
# codigo_ocorrencia                               39527
# codigo_ocorrencia1                              39527
# codigo_ocorrencia2                              39527
# codigo_ocorrencia3                              39527
# codigo_ocorrencia4                              39527
# ocorrencia_classificacao                     ACIDENTE
# ocorrencia_latitude                    -13.1066666667
# ocorrencia_longitude                   -55.9930555556
# ocorrencia_cidade                  LUCAS DO RIO VERDE
# ocorrencia_uf                                      MT
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             ****
# ocorrencia_dia                    2010-01-04 00:00:00
# ocorrencia_hora                              17:30:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero         A-539/CENIPA/2018
# ...

# %% [markdown]
# PEGAR OS DADOS DA LINHA1 ATÉ A LINHA 3

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# ...

# %% [markdown]
# TRAZER DADOS DA LINHA 10 E 40 (sem informar a coluna)

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# ...

# %% [markdown]
# PEGAR TODOS OS DADOS DA COLUNA SEM INFORMA AS LINHAS
# df.loc[:, Nome da Coluna]

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %% [markdown]
# REALIZANDO A LIMPEZA DOS DADOS - PARTE 2

# %% [markdown]
# VRIFICAR SE O CAMPO TEM VALORES ÚNICOS PARA LINHAS DIFERENTES

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# Como é unico vou utilizá-lo como índice no DataFrame, no código abaixo não atualizo o DataFrame
# Não fiz alteração no DataFrame

# %%
df.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
# ...                               ...                 ...                 ...
# 79804                           79804               79804               79804
# 79757                           79757               79757               79757
# 79802                           79802               79802               79802
# 79756                           79756               79756               79756
# 79844                           79844               79844               79844
#
# ...

# %% [markdown]
# PARA FAZER A ALTERAÇÃO NO DataFrame

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %% [markdown]
# AGORA TENHO "codigo_ocorrencia" COMO ÍNDICE DO DataFrame

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# ...

# %% [markdown]
# AGORA PARA OBTER OS DADOS, TENHO QUE USAR ESSE ÍNDICE NO DataFrame

# %%
# Retorna todos os dados dessa linha referente ao índice ou label 40349
df.loc[40349]
# Out:
# codigo_ocorrencia1                              40349
# codigo_ocorrencia2                              40349
# codigo_ocorrencia3                              40349
# codigo_ocorrencia4                              40349
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                               BELÉM
# ocorrencia_uf                                      PA
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBBE
# ocorrencia_dia                    2010-01-03 00:00:00
# ocorrencia_hora                              11:05:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# ...

# %% [markdown]
# REMOVER O ÍNDICE DO DataFrame, VOLTAR AO ORIGINAL

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %% [markdown]
# COMO ALTERAR OS DADOS DO campo "ocorrencia_aerodromo"

# %%
df.ocorrencia_aerodromo
# Out:
# 0       ****
# 1       SBBE
# 2       SBRJ
# 3       ****
# 4       SBPK
#         ...
# 5747    SBKP
# 5748    ****
# 5749    SBGL
# 5750    ****
# 5751    SBJR
# Name: ocorrencia_aerodromo, Length: 5752, dtype: object

# %% [markdown]
# PASSAR CONTEÚDO Do ÍNDICE 0 CAMPO "ocorrencia_aerodromo" PARA VAZIO

# %%
df.loc[0,"ocorrencia_aerodromo"] = ''

# %%
df.ocorrencia_aerodromo
# Out:
# 0
# 1       SBBE
# 2       SBRJ
# 3       ****
# 4       SBPK
#         ...
# 5747    SBKP
# 5748    ****
# 5749    SBGL
# 5750    ****
# 5751    SBJR
# Name: ocorrencia_aerodromo, Length: 5752, dtype: object

# %% [markdown]
# ALTERAR TODOS OS DADOS DE UMA LINHA - Não faz muito sentido
# TODOS OS DADOS DA LINHA 1

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2010-01-03 00:00:00        12:00:00                            SIM
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
# ...

# %% [markdown]
# ALTERAR O DADO DE TODAS AS LINHA DE UMA COLUNA
# Exemplo: total_recomendacoes - ALTERAR PARA 10

# %%
df.loc[:,'total_recomendacoes'] = 10

# %%
df.total_recomendacoes
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
#         ..
# 5747    10
# 5748    10
# 5749    10
# 5750    10
# 5751    10
# Name: total_recomendacoes, Length: 5752, dtype: int64

# %% [markdown]
# FAZENDO O BACKUP DE UMA COLUNA, CRIA NA ULTIMA POSICAO A COLUNA CRIADA

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                     20                  20                  20
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 5747               79804               79804               79804
# 5748               79757               79757               79757
# 5749               79802               79802               79802
# 5750               79756               79756               79756
# 5751               79844               79844               79844
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %% [raw]
# ALTERAR CONTEÚDO DA COLUNA ocorrencia_classificacao ONDE A COLUNA ocorrencia_uf = SP  PARA "GRAVE"

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %% [markdown]
# TODOS DA ocorrecia_uf = 'SP' FORAM ALTERADOS PARA 'GRAVE'
# LISTANDO APENAS OS CAMPOS ocorrencia_uf E ocorrencia_classificacao

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_uf', 'ocorrencia_classificacao']]
# Out:
#      ocorrencia_uf ocorrencia_classificacao
# 11              SP                    GRAVE
# 16              SP                    GRAVE
# 18              SP                    GRAVE
# 26              SP                    GRAVE
# 27              SP                    GRAVE
# ...            ...                      ...
# 5704            SP                    GRAVE
# 5705            SP                    GRAVE
# 5715            SP                    GRAVE
# 5742            SP                    GRAVE
# 5747            SP                    GRAVE
#
# [1373 rows x 2 columns]

# %% [markdown]
# VOLTAR O DATAFRAME AO ESTADO ORIGINAL

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %% [raw]
# EFETUAR A LIMPEZA - LIMPAR OS DADOS NÃO INF0RMADOS
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ****
# *****
# ####

# %% [markdown]
# LIMPAR TODAS LINHAS QUE TEM **
# NA -not available - atribuir valores que não estão disponíveis na célula

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %% [markdown]
# FUNÇÃO:  replace - FAZER TODAS MODIFICAÇÕES DE UMA VEZ
# df.replace(['**', '*****','NULL']

# %%
df.replace(['**','***', '*****','NULL'], pd.NA, inplace = True)

# %%
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                <NA>                 <NA>      RIO DE JANEIRO            RJ
# ...

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 5747               79804               79804                INCIDENTE
# 5748               79757               79757          INCIDENTE GRAVE
# 5749               79802               79802                INCIDENTE
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude  ocorrencia_cidade  \
# 5747      -23.0069444444       -47.1344444444           CAMPINAS
# ...

# %% [markdown]
# QUANTOS (NAs - Não Informado) TENHO NO DATAFRAME
# DADO NÃO INFORMADO: retorna True
# Função: isna() e isnull()

# %%
df.isna().head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              False               False               False
# 1              False               False               False
# 2              False               False               False
# 3              False               False               False
# 4              False               False               False
#
#    codigo_ocorrencia3  codigo_ocorrencia4  ocorrencia_classificacao  \
# 0               False               False                     False
# 1               False               False                     False
# 2               False               False                     False
# 3               False               False                     False
# 4               False               False                     False
#
#    ocorrencia_latitude  ocorrencia_longitude  ocorrencia_cidade  \
# 0                 True                  True              False
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2293
# ocorrencia_longitude              2295
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2331
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %%
df.isnull().head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              False               False               False
# 1              False               False               False
# 2              False               False               False
# 3              False               False               False
# 4              False               False               False
#
#    codigo_ocorrencia3  codigo_ocorrencia4  ocorrencia_classificacao  \
# 0               False               False                     False
# 1               False               False                     False
# 2               False               False                     False
# 3               False               False                     False
# 4               False               False                     False
#
#    ocorrencia_latitude  ocorrencia_longitude  ocorrencia_cidade  \
# 0                 True                  True              False
# ...

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2293
# ocorrencia_longitude              2295
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2331
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# COLOCAR VALORES NOS DADOS NÃO INFORMADOS
# COLOCAR VALOR (10) EM TODOS OS DADOS NÃO INFORMADOS
# *** MUDA APENAS EM TEMPO DE VISUALIZAÇÃO ***
# **** PARA SALVAR AS ALTERAÇÕES ****
# inplace=True

# %%
df.fillna(10, inplace=True)

# %% [markdown]
# NÃO RETORNA NENHUM COM VALO (NA)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                 0
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                  10                   10      RIO DE JANEIRO            RJ
# ...

# %% [markdown]
# PEGAR TODOS CAMPOS COM VALOR (10) SUBSTITUIR POR (NA)

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2293
# ocorrencia_longitude              2295
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2331
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  2
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# ALTERAR ALGUNS LOCAIS QUE TENHA (NA) PARA O VALOR (10)

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %% [raw]
# total_recomendacoes voltou a ficar (0)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2293
# ocorrencia_longitude              2295
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2331
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# REALIZANDO A LIMPEZA DE DADOS - PARTE 4

# %% [markdown]
# CRIAR UMA COLUNA (total_recomendacoes_bkp) RECEBENDO DADOS DE (total_recomendacoes)

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#   codigo_ocorrencia codigo_ocorrencia1 codigo_ocorrencia2 codigo_ocorrencia3  \
# 0             40211              40211              40211              40211
# 1             40349              40349              40349              40349
# 2             40351              40351              40351              40351
# 3             39527              39527              39527              39527
# 4             40324              40324              40324              40324
#
#   codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0              40211                INCIDENTE                <NA>
# 1              40349                INCIDENTE                <NA>
# 2              40351                INCIDENTE                <NA>
# 3              39527                 ACIDENTE      -13.1066666667
# 4              40324                INCIDENTE                <NA>
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# ...

# %% [markdown]
# EXCLUIR COLUNA (total_recomendacoes_bkp)
# DARÁ ERRO, POR PADRÃO TENTA APAGAR A LINHA.
# POR PADRÃO O EIXO = 0 ( COLUNA )
# PARA PODER APAGAR MUDAR O (eixo) para 1 ( LINHA )

# %%
df.drop(['total_recomendacoes_bkp'])
# Out:
# -----------------------------------------------------------------
# KeyError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9384/298850791.py in <module>
# ----> 1 df.drop(['total_recomendacoes_bkp'])
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
PARA PODER APAGAR MUDAR O (eixo) para 1 ( LINHA )
inplace=True -- Atualizar o DataFrame
A coluna (total_recomendacoes_bkp) será excluída
# Out:
#   File "C:\Users\marco\AppData\Local\Temp/ipykernel_9384/3365894994.py", line 1
#     PARA PODER APAGAR MUDAR O (eixo) para 1 ( LINHA )
#          ^
# SyntaxError: invalid syntax

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %% [markdown]
# EXCLUI TODAS AS LINHAS COM CAMPOS (NA)
# ****** NÃO USAR ********

# %%
# df.dropna()

# %% [markdown]
# EXCLUI AS LINHAS CAMPOS COM (NA) ESPECIFICANDO A COLUNA

# %%
# df.dropna(subset=['ocorrencia_uf'])

# %%
df
# Out:
#      codigo_ocorrencia codigo_ocorrencia1 codigo_ocorrencia2  \
# 0                40211              40211              40211
# 1                40349              40349              40349
# 2                40351              40351              40351
# 3                39527              39527              39527
# 4                40324              40324              40324
# ...                ...                ...                ...
# 5747             79804              79804              79804
# 5748             79757              79757              79757
# 5749             79802              79802              79802
# 5750             79756              79756              79756
# 5751             79844              79844              79844
#
#      codigo_ocorrencia3 codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                 40211              40211                INCIDENTE
# 1                 40349              40349                INCIDENTE
# ...

# %% [markdown]
# Exclui linhas duplicadas
# Não haverá linhas duplicadas
# PARA SALVAR NO DataFrame
# df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates()
# Out:
#      codigo_ocorrencia codigo_ocorrencia1 codigo_ocorrencia2  \
# 0                40211              40211              40211
# 1                40349              40349              40349
# 2                40351              40351              40351
# 3                39527              39527              39527
# 4                40324              40324              40324
# ...                ...                ...                ...
# 5747             79804              79804              79804
# 5748             79757              79757              79757
# 5749             79802              79802              79802
# 5750             79756              79756              79756
# 5751             79844              79844              79844
#
#      codigo_ocorrencia3 codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                 40211              40211                INCIDENTE
# 1                 40349              40349                INCIDENTE
# ...

# %% [raw]
# Missing Values = Dados não informados (NA) DO PANDAS
# Também é tratado com outro classificador
# NAM not anumeric utilizando a bivlioteca numpy e atribui pelo numpy o NAM num dado não informado
# ----------------------------------------
# Dado outlayer - extrapola uma média que temos
